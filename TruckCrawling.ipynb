# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time 
import os 
import urllib.request

def createFolder(directory): 
    try: 
        if not os.path.exists(directory): 
            os.makedirs(directory) 
    except OSError: 
        print ('Error: Creating directory. ' + directory)
        
keyword='truck' 
createFolder('./'+keyword+'_img') 
chromedriver = 'C://Users//park3//park//chromedriver.exe'
driver = webdriver.Chrome(chromedriver) 
driver.implicitly_wait(3)

# %%
print(keyword, '검색') 
driver.get('https://www.google.co.kr/imghp?hl=ko') 
Keyword=driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input') 
Keyword.send_keys(keyword) 
driver.find_element_by_xpath('//*[@id="sbtc"]/button').click()
# Out:
# truck 검색

# %%
print(keyword+' 스크롤 중 .............') 
elem = driver.find_element_by_tag_name("body") 
for i in range(50): 
    elem.send_keys(Keys.PAGE_DOWN) 
    time.sleep(0.1) 

try: 
    driver.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div[1]/div[4]/div[2]/input').click() 
    for i in range(60): 
        elem.send_keys(Keys.PAGE_DOWN) 
        time.sleep(0.1) 
except: 
    pass
# Out:
# truck 스크롤 중 .............

# %%
links=[] 
images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd") 
for image in images: 
    if image.get_attribute('src')!=None: 
        links.append(image.get_attribute('src')) 
        print(keyword+' 찾은 이미지 개수:',len(links)) 
        time.sleep(2)
# Out:
# truck 찾은 이미지 개수: 1
# truck 찾은 이미지 개수: 2
# truck 찾은 이미지 개수: 3
# truck 찾은 이미지 개수: 4
# truck 찾은 이미지 개수: 5
# truck 찾은 이미지 개수: 6
# truck 찾은 이미지 개수: 7
# truck 찾은 이미지 개수: 8
# truck 찾은 이미지 개수: 9
# truck 찾은 이미지 개수: 10
# truck 찾은 이미지 개수: 11
# truck 찾은 이미지 개수: 12
# truck 찾은 이미지 개수: 13
# truck 찾은 이미지 개수: 14
# truck 찾은 이미지 개수: 15
# truck 찾은 이미지 개수: 16
# truck 찾은 이미지 개수: 17
# truck 찾은 이미지 개수: 18
# truck 찾은 이미지 개수: 19
# truck 찾은 이미지 개수: 20
# truck 찾은 이미지 개수: 21
# truck 찾은 이미지 개수: 22
# truck 찾은 이미지 개수: 23
# truck 찾은 이미지 개수: 24
# truck 찾은 이미지 개수: 25
# truck 찾은 이미지 개수: 26
# truck 찾은 이미지 개수: 27
# truck 찾은 이미지 개수: 28
# truck 찾은 이미지 개수: 29
# truck 찾은 이미지 개수: 30
# truck 찾은 이미지 개수: 31
# truck 찾은 이미지 개수: 32
# truck 찾은 이미지 개수: 33
# truck 찾은 이미지 개수: 34
# truck 찾은 이미지 개수: 35
# truck 찾은 이미지 개수: 36
# truck 찾은 이미지 개수: 37
# truck 찾은 이미지 개수: 38
# truck 찾은 이미지 개수: 39
# truck 찾은 이미지 개수: 40
# truck 찾은 이미지 개수: 41
# truck 찾은 이미지 개수: 42
# truck 찾은 이미지 개수: 43
# truck 찾은 이미지 개수: 44
# truck 찾은 이미지 개수: 45
# truck 찾은 이미지 개수: 46
# truck 찾은 이미지 개수: 47
# truck 찾은 이미지 개수: 48
# truck 찾은 이미지 개수: 49
# truck 찾은 이미지 개수: 50
# truck 찾은 이미지 개수: 51
# truck 찾은 이미지 개수: 52
# truck 찾은 이미지 개수: 53
# truck 찾은 이미지 개수: 54
# truck 찾은 이미지 개수: 55
# truck 찾은 이미지 개수: 56
# truck 찾은 이미지 개수: 57
# truck 찾은 이미지 개수: 58
# truck 찾은 이미지 개수: 59
# truck 찾은 이미지 개수: 60
# truck 찾은 이미지 개수: 61
# truck 찾은 이미지 개수: 62
# truck 찾은 이미지 개수: 63
# truck 찾은 이미지 개수: 64
# truck 찾은 이미지 개수: 65
# truck 찾은 이미지 개수: 66
# truck 찾은 이미지 개수: 67
# truck 찾은 이미지 개수: 68
# truck 찾은 이미지 개수: 69
# truck 찾은 이미지 개수: 70
# truck 찾은 이미지 개수: 71
# truck 찾은 이미지 개수: 72
# truck 찾은 이미지 개수: 73
# truck 찾은 이미지 개수: 74
# truck 찾은 이미지 개수: 75
# truck 찾은 이미지 개수: 76
# truck 찾은 이미지 개수: 77
# truck 찾은 이미지 개수: 78
# truck 찾은 이미지 개수: 79
# truck 찾은 이미지 개수: 80
# truck 찾은 이미지 개수: 81
# truck 찾은 이미지 개수: 82
# truck 찾은 이미지 개수: 83
# truck 찾은 이미지 개수: 84
# truck 찾은 이미지 개수: 85
# truck 찾은 이미지 개수: 86
# truck 찾은 이미지 개수: 87
# truck 찾은 이미지 개수: 88
# truck 찾은 이미지 개수: 89
# truck 찾은 이미지 개수: 90
# truck 찾은 이미지 개수: 91
# truck 찾은 이미지 개수: 92
# truck 찾은 이미지 개수: 93
# truck 찾은 이미지 개수: 94
# truck 찾은 이미지 개수: 95
# truck 찾은 이미지 개수: 96
# truck 찾은 이미지 개수: 97
# truck 찾은 이미지 개수: 98
# truck 찾은 이미지 개수: 99
# truck 찾은 이미지 개수: 100
# truck 찾은 이미지 개수: 101
# truck 찾은 이미지 개수: 102
# truck 찾은 이미지 개수: 103
# truck 찾은 이미지 개수: 104
# truck 찾은 이미지 개수: 105
# truck 찾은 이미지 개수: 106
# truck 찾은 이미지 개수: 107
# truck 찾은 이미지 개수: 108
# truck 찾은 이미지 개수: 109
# truck 찾은 이미지 개수: 110
# truck 찾은 이미지 개수: 111
# truck 찾은 이미지 개수: 112
# truck 찾은 이미지 개수: 113
# truck 찾은 이미지 개수: 114
# truck 찾은 이미지 개수: 115
# truck 찾은 이미지 개수: 116
# truck 찾은 이미지 개수: 117
# truck 찾은 이미지 개수: 118
# truck 찾은 이미지 개수: 119
# truck 찾은 이미지 개수: 120
# truck 찾은 이미지 개수: 121
# truck 찾은 이미지 개수: 122
# truck 찾은 이미지 개수: 123
# truck 찾은 이미지 개수: 124
# truck 찾은 이미지 개수: 125
# truck 찾은 이미지 개수: 126
# truck 찾은 이미지 개수: 127
# truck 찾은 이미지 개수: 128
# truck 찾은 이미지 개수: 129
# truck 찾은 이미지 개수: 130
# truck 찾은 이미지 개수: 131
# truck 찾은 이미지 개수: 132
# truck 찾은 이미지 개수: 133
# truck 찾은 이미지 개수: 134
# truck 찾은 이미지 개수: 135
# truck 찾은 이미지 개수: 136
# truck 찾은 이미지 개수: 137
# truck 찾은 이미지 개수: 138
# truck 찾은 이미지 개수: 139
# truck 찾은 이미지 개수: 140
# truck 찾은 이미지 개수: 141
# truck 찾은 이미지 개수: 142
# truck 찾은 이미지 개수: 143
# truck 찾은 이미지 개수: 144
# truck 찾은 이미지 개수: 145
# truck 찾은 이미지 개수: 146
# truck 찾은 이미지 개수: 147
# truck 찾은 이미지 개수: 148
# truck 찾은 이미지 개수: 149
# truck 찾은 이미지 개수: 150
# truck 찾은 이미지 개수: 151
# truck 찾은 이미지 개수: 152
# truck 찾은 이미지 개수: 153
# truck 찾은 이미지 개수: 154
# truck 찾은 이미지 개수: 155
# truck 찾은 이미지 개수: 156
# truck 찾은 이미지 개수: 157
# truck 찾은 이미지 개수: 158
# truck 찾은 이미지 개수: 159
# truck 찾은 이미지 개수: 160
# truck 찾은 이미지 개수: 161
# truck 찾은 이미지 개수: 162
# truck 찾은 이미지 개수: 163
# truck 찾은 이미지 개수: 164
# truck 찾은 이미지 개수: 165
# truck 찾은 이미지 개수: 166
# truck 찾은 이미지 개수: 167
# truck 찾은 이미지 개수: 168
# truck 찾은 이미지 개수: 169
# truck 찾은 이미지 개수: 170
# truck 찾은 이미지 개수: 171
# truck 찾은 이미지 개수: 172
# truck 찾은 이미지 개수: 173
# truck 찾은 이미지 개수: 174
# truck 찾은 이미지 개수: 175
# truck 찾은 이미지 개수: 176
# truck 찾은 이미지 개수: 177
# truck 찾은 이미지 개수: 178
# truck 찾은 이미지 개수: 179
# truck 찾은 이미지 개수: 180
# truck 찾은 이미지 개수: 181
# truck 찾은 이미지 개수: 182
# truck 찾은 이미지 개수: 183
# truck 찾은 이미지 개수: 184
# truck 찾은 이미지 개수: 185
# truck 찾은 이미지 개수: 186
# truck 찾은 이미지 개수: 187
# truck 찾은 이미지 개수: 188
# truck 찾은 이미지 개수: 189
# truck 찾은 이미지 개수: 190
# truck 찾은 이미지 개수: 191
# truck 찾은 이미지 개수: 192
# truck 찾은 이미지 개수: 193
# truck 찾은 이미지 개수: 194
# truck 찾은 이미지 개수: 195
# truck 찾은 이미지 개수: 196
# truck 찾은 이미지 개수: 197
# truck 찾은 이미지 개수: 198
# truck 찾은 이미지 개수: 199
# truck 찾은 이미지 개수: 200
# truck 찾은 이미지 개수: 201
# truck 찾은 이미지 개수: 202
# truck 찾은 이미지 개수: 203
# truck 찾은 이미지 개수: 204
# truck 찾은 이미지 개수: 205
# truck 찾은 이미지 개수: 206
# truck 찾은 이미지 개수: 207
# truck 찾은 이미지 개수: 208
# truck 찾은 이미지 개수: 209
# truck 찾은 이미지 개수: 210
# truck 찾은 이미지 개수: 211
# truck 찾은 이미지 개수: 212
# truck 찾은 이미지 개수: 213
# truck 찾은 이미지 개수: 214
# truck 찾은 이미지 개수: 215
# truck 찾은 이미지 개수: 216
# truck 찾은 이미지 개수: 217
# truck 찾은 이미지 개수: 218
# truck 찾은 이미지 개수: 219
# truck 찾은 이미지 개수: 220
# truck 찾은 이미지 개수: 221
# truck 찾은 이미지 개수: 222
# truck 찾은 이미지 개수: 223
# truck 찾은 이미지 개수: 224
# truck 찾은 이미지 개수: 225
# truck 찾은 이미지 개수: 226
# truck 찾은 이미지 개수: 227
# truck 찾은 이미지 개수: 228
# truck 찾은 이미지 개수: 229
# truck 찾은 이미지 개수: 230
# truck 찾은 이미지 개수: 231
# truck 찾은 이미지 개수: 232
# truck 찾은 이미지 개수: 233
# truck 찾은 이미지 개수: 234
# truck 찾은 이미지 개수: 235
# truck 찾은 이미지 개수: 236
# truck 찾은 이미지 개수: 237
# truck 찾은 이미지 개수: 238
# truck 찾은 이미지 개수: 239
# truck 찾은 이미지 개수: 240
# truck 찾은 이미지 개수: 241
# truck 찾은 이미지 개수: 242
# truck 찾은 이미지 개수: 243
# truck 찾은 이미지 개수: 244
# truck 찾은 이미지 개수: 245
# truck 찾은 이미지 개수: 246
# truck 찾은 이미지 개수: 247
# truck 찾은 이미지 개수: 248
# truck 찾은 이미지 개수: 249
# truck 찾은 이미지 개수: 250
# truck 찾은 이미지 개수: 251
# truck 찾은 이미지 개수: 252
# truck 찾은 이미지 개수: 253
# truck 찾은 이미지 개수: 254
# truck 찾은 이미지 개수: 255
# truck 찾은 이미지 개수: 256
# truck 찾은 이미지 개수: 257
# truck 찾은 이미지 개수: 258
# truck 찾은 이미지 개수: 259
# truck 찾은 이미지 개수: 260
# truck 찾은 이미지 개수: 261
# truck 찾은 이미지 개수: 262
# truck 찾은 이미지 개수: 263
# truck 찾은 이미지 개수: 264
# truck 찾은 이미지 개수: 265
# truck 찾은 이미지 개수: 266
# truck 찾은 이미지 개수: 267
# truck 찾은 이미지 개수: 268
# truck 찾은 이미지 개수: 269
# truck 찾은 이미지 개수: 270
# truck 찾은 이미지 개수: 271
# truck 찾은 이미지 개수: 272
# truck 찾은 이미지 개수: 273
# truck 찾은 이미지 개수: 274
# truck 찾은 이미지 개수: 275
# truck 찾은 이미지 개수: 276
# truck 찾은 이미지 개수: 277
# truck 찾은 이미지 개수: 278
# truck 찾은 이미지 개수: 279
# truck 찾은 이미지 개수: 280
# truck 찾은 이미지 개수: 281
# truck 찾은 이미지 개수: 282
# truck 찾은 이미지 개수: 283
# truck 찾은 이미지 개수: 284
# truck 찾은 이미지 개수: 285
# truck 찾은 이미지 개수: 286
# truck 찾은 이미지 개수: 287
# truck 찾은 이미지 개수: 288
# truck 찾은 이미지 개수: 289
# truck 찾은 이미지 개수: 290
# truck 찾은 이미지 개수: 291
# truck 찾은 이미지 개수: 292
# truck 찾은 이미지 개수: 293
# truck 찾은 이미지 개수: 294
# truck 찾은 이미지 개수: 295
# truck 찾은 이미지 개수: 296
# truck 찾은 이미지 개수: 297
# truck 찾은 이미지 개수: 298
# truck 찾은 이미지 개수: 299
# truck 찾은 이미지 개수: 300
# truck 찾은 이미지 개수: 301
# truck 찾은 이미지 개수: 302
# truck 찾은 이미지 개수: 303
# truck 찾은 이미지 개수: 304
# truck 찾은 이미지 개수: 305
# truck 찾은 이미지 개수: 306
# truck 찾은 이미지 개수: 307
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time 
import os
import urllib.request 
from multiprocessing import Pool 
import pandas as pd 

keyword='트럭'

def createFolder(directory): 
    try: 
        if not os.path.exists(directory):
            os.makedirs(directory) 
    except OSError: 
        print ('Error: Creating directory. ' + directory) 
def image_download(keyword): 
    createFolder('./'+keyword+'_high resolution') 
    chromedriver = 'C://Users//park3//park//chromedriver.exe' 
    driver = webdriver.Chrome(chromedriver) 
    driver.implicitly_wait(3) 
    print(keyword, '검색') 
    driver.get('https://www.google.co.kr/imghp?hl=ko') 
    Keyword=driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input') 
    Keyword.send_keys(keyword) 
    driver.find_element_by_xpath('//*[@id="sbtc"]/button').click() 
    print(keyword+' 스크롤 중 .............') 
    elem = driver.find_element_by_tag_name("body") 
    for i in range(60): 
        elem.send_keys(Keys.PAGE_DOWN) 
        time.sleep(0.1) 
    try: 
        driver.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div[1]/div[4]/div[2]/input').click()
        for i in range(60): 
            elem.send_keys(Keys.PAGE_DOWN)
            time.sleep(0.1) 
    except:
        pass 
    images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd") 
    print(keyword+' 찾은 이미지 개수:',len(images)) 
    links=[] 
    for i in range(1,len(images)): 
#         try: 
        driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').click() 
        links.append(driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute('src'))
        driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[2]/a').click() 
        print(keyword+' 링크 수집 중..... number :'+str(i)+'/'+str(len(images))) 
#         except: 
#             print('error2')
#             continue 
        forbidden=0 
    for k,i in enumerate(links):
        try: 
            url = i 
            start = time.time() 
            urllib.request.urlretrieve(url, "./"+keyword+"_high resolution/"+keyword+"_"+str(k-forbidden)+".jpg") 
            print(str(k+1)+'/'+str(len(links))+' '+keyword+' 다운로드 중....... Download time : '+str(time.time() - start)[:5]+' 초') 
        except: 
            print('error3')
            forbidden+=1        
            continue 
    print(keyword+' ---다운로드 완료---')
    driver.close() 
# ============================================================================= # 실행 # ============================================================================= 
image_download(keyword)
# Out:
# 트럭 검색
# 트럭 스크롤 중 .............
# error1
# 트럭 찾은 이미지 개수: 400
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28572/569293223.py in <module>
#      64     driver.close()
#      65 # ============================================================================= # 실행 # =============================================================================
# ---> 66 image_download(keyword)
#
# ~\AppData\Local\Temp/ipykernel_28572/569293223.py in image_download(keyword)
#      44 #         try:
#      45         driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').click()
# ---> 46         links.append(driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute('src'))
#      47         driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[2]/a').click()
#      48         print(keyword+' 링크 수집 중..... number :'+str(i)+'/'+str(len(images)))
#
# ~\anaconda3\envs\data\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\data\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\envs\data\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\data\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img"}
#   (Session info: chrome=94.0.4606.61)
